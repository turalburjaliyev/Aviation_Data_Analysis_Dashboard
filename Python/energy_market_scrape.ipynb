# %%
import yfinance as yf

tickers = ["BZ=F", "CL=F", "RB=F", "HO=F"]
data = yf.download(tickers, start="2015-01-01")["Close"]
data.to_csv("energy_markets.csv")
print(data.head())
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker           BZ=F       CL=F    HO=F    RB=F
# Date
# 2015-01-02  56.419998  52.689999  1.7957  1.4334
# 2015-01-05  53.110001  50.040001  1.7492  1.3814
# 2015-01-06  51.099998  47.930000  1.7262  1.3543
# 2015-01-07  51.150002  48.650002  1.6999  1.3376
# 2015-01-08  50.959999  48.790001  1.7110  1.3409
